# %%
import pandas as pd
import numpy as np
import seaborn as sea
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/delivery_dataset_cleaned.csv')

# %% [markdown]
# 1. Inspecting the dataset

# %%
# df = df.drop(columns=['Unnamed: 0'])

df['dismissal_kind'] = df['dismissal_kind'].fillna('N/A')
df['fielder'] = df['fielder'].fillna('N/A')

# %%
display(df.shape)
# Out:
# (150459, 21)

# %%
df.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
display(df.head())
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
display(df.describe())
# Out:
#             match_id         inning           over           ball  \
# count  150459.000000  150459.000000  150459.000000  150459.000000
# mean      318.281964       1.482191      10.142690       3.616500
# std       182.955967       0.501768       5.674335       1.807691
# min         1.000000       1.000000       1.000000       1.000000
# 25%       161.000000       1.000000       5.000000       2.000000
# 50%       319.000000       1.000000      10.000000       4.000000
# 75%       476.000000       2.000000      15.000000       5.000000
# max       636.000000       4.000000      20.000000       9.000000
#
#        is_super_over      wide_runs       bye_runs    legbye_runs  \
# count  150459.000000  150459.000000  150459.000000  150459.000000
# mean        0.000538       0.037499       0.004885       0.022232
# std         0.023196       0.257398       0.114235       0.200105
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
display(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150459 entries, 0 to 150458
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          150459 non-null  int64
#  1   inning            150459 non-null  int64
#  2   batting_team      150459 non-null  object
#  3   bowling_team      150459 non-null  object
#  4   over              150459 non-null  int64
#  5   ball              150459 non-null  int64
#  6   batsman           150459 non-null  object
#  7   non_striker       150459 non-null  object
#  8   bowler            150459 non-null  object
#  9   is_super_over     150459 non-null  int64
#  10  wide_runs         150459 non-null  int64
#  11  bye_runs          150459 non-null  int64
#  12  legbye_runs       150459 non-null  int64
#  13  noball_runs       150459 non-null  int64
#  14  penalty_runs      150459 non-null  int64
#  15  batsman_runs      150459 non-null  int64
# ...

# %%
display(df.index)
# Out:
# RangeIndex(start=0, stop=150459, step=1)

# %%
display(df.describe(include='all'))
# Out:
#              match_id         inning    batting_team    bowling_team  \
# count   150459.000000  150459.000000          150459          150459
# unique            NaN            NaN              12              12
# top               NaN            NaN  Mumbai Indians  Mumbai Indians
# freq              NaN            NaN           18942           18879
# mean       318.281964       1.482191             NaN             NaN
# std        182.955967       0.501768             NaN             NaN
# min          1.000000       1.000000             NaN             NaN
# 25%        161.000000       1.000000             NaN             NaN
# 50%        319.000000       1.000000             NaN             NaN
# 75%        476.000000       2.000000             NaN             NaN
# max        636.000000       4.000000             NaN             NaN
#
#                  over           ball  batsman non_striker           bowler  \
# ...

# %%
display(df.dtypes)
# Out:
# match_id             int64
# inning               int64
# batting_team        object
# bowling_team        object
# over                 int64
# ball                 int64
# batsman             object
# non_striker         object
# bowler              object
# is_super_over        int64
# wide_runs            int64
# bye_runs             int64
# legbye_runs          int64
# noball_runs          int64
# penalty_runs         int64
# batsman_runs         int64
# extra_runs           int64
# total_runs           int64
# player_dismissed    object
# dismissal_kind      object
# fielder             object
# dtype: object

# %%
display(df.memory_usage(deep=True))
# Out:
# Index                    132
# match_id             1203672
# inning               1203672
# batting_team        10019527
# bowling_team        10023663
# over                 1203672
# ball                 1203672
# batsman              8785246
# non_striker          8785382
# bowler               8797137
# is_super_over        1203672
# wide_runs            1203672
# bye_runs             1203672
# legbye_runs          1203672
# noball_runs          1203672
# penalty_runs         1203672
# batsman_runs         1203672
# extra_runs           1203672
# total_runs           1203672
# player_dismissed     8443747
# dismissal_kind       7848241
# fielder              7858916
# dtype: int64

# %%
display(df.nunique())
# Out:
# match_id            636
# inning                4
# batting_team         12
# bowling_team         12
# over                 20
# ball                  9
# batsman             461
# non_striker         458
# bowler              356
# is_super_over         2
# wide_runs             6
# bye_runs              5
# legbye_runs           6
# noball_runs           5
# penalty_runs          2
# batsman_runs          7
# extra_runs            7
# total_runs            8
# player_dismissed    437
# dismissal_kind       10
# fielder             452
# dtype: int64

# %%
display(df.isna().mean())
display(df.isna().mean()*100)
# Out:
# match_id            0.0
# inning              0.0
# batting_team        0.0
# bowling_team        0.0
# over                0.0
# ball                0.0
# batsman             0.0
# non_striker         0.0
# bowler              0.0
# is_super_over       0.0
# wide_runs           0.0
# bye_runs            0.0
# legbye_runs         0.0
# noball_runs         0.0
# penalty_runs        0.0
# batsman_runs        0.0
# extra_runs          0.0
# total_runs          0.0
# player_dismissed    0.0
# dismissal_kind      0.0
# fielder             0.0
# dtype: float64
# match_id            0.0
# inning              0.0
# batting_team        0.0
# bowling_team        0.0
# over                0.0
# ball                0.0
# batsman             0.0
# non_striker         0.0
# bowler              0.0
# is_super_over       0.0
# wide_runs           0.0
# bye_runs            0.0
# legbye_runs         0.0
# noball_runs         0.0
# penalty_runs        0.0
# batsman_runs        0.0
# ...

# %%
display(df.duplicated().sum())
# Out:
# np.int64(0)

# %% [markdown]
# 2. Boolean Filtering

# %%
df.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
#CSK matches


display(df[(df['batting_team'] == 'Chennai Super Kings') | (df['bowling_team'] == 'Chennai Super Kings')])
# Out:
#         match_id  inning         batting_team    bowling_team  over  ball  \
# 14087         61       1  Chennai Super Kings    Punjab Kings     1     1
# 14088         61       1  Chennai Super Kings    Punjab Kings     1     2
# 14089         61       1  Chennai Super Kings    Punjab Kings     1     3
# 14090         61       1  Chennai Super Kings    Punjab Kings     1     4
# 14091         61       1  Chennai Super Kings    Punjab Kings     1     5
# ...          ...     ...                  ...             ...   ...   ...
# 136358       576       2  Chennai Super Kings  Mumbai Indians    20     2
# 136359       576       2  Chennai Super Kings  Mumbai Indians    20     3
# 136360       576       2  Chennai Super Kings  Mumbai Indians    20     4
# 136361       576       2  Chennai Super Kings  Mumbai Indians    20     5
# 136362       576       2  Chennai Super Kings  Mumbai Indians    20     6
#
#           batsman non_striker         bowler  is_super_over  ...  bye_runs  \
# ...

# %%
# MI matches
display(df[(df['batting_team'] == 'Mumbai Indians') | (df['bowling_team'] == 'Mumbai Indians')])
# Out:
#         match_id  inning    batting_team            bowling_team  over  ball  \
# 248            2       1  Mumbai Indians  Rising Pune Supergiant     1     1
# 249            2       1  Mumbai Indians  Rising Pune Supergiant     1     2
# 250            2       1  Mumbai Indians  Rising Pune Supergiant     1     3
# 251            2       1  Mumbai Indians  Rising Pune Supergiant     1     4
# 252            2       1  Mumbai Indians  Rising Pune Supergiant     1     5
# ...          ...     ...             ...                     ...   ...   ...
# 148995       630       2   Gujarat Lions          Mumbai Indians    18     1
# 148996       630       2   Gujarat Lions          Mumbai Indians    18     2
# 148997       630       2   Gujarat Lions          Mumbai Indians    18     3
# 148998       630       2   Gujarat Lions          Mumbai Indians    18     4
# 148999       630       2   Gujarat Lions          Mumbai Indians    18     5
#
# ...

# %%
display(df.query("bowling_team == 'Chennai Super Kings' or batting_team == 'Chennai Super Kings'"))
# Out:
#         match_id  inning         batting_team    bowling_team  over  ball  \
# 14087         61       1  Chennai Super Kings    Punjab Kings     1     1
# 14088         61       1  Chennai Super Kings    Punjab Kings     1     2
# 14089         61       1  Chennai Super Kings    Punjab Kings     1     3
# 14090         61       1  Chennai Super Kings    Punjab Kings     1     4
# 14091         61       1  Chennai Super Kings    Punjab Kings     1     5
# ...          ...     ...                  ...             ...   ...   ...
# 136358       576       2  Chennai Super Kings  Mumbai Indians    20     2
# 136359       576       2  Chennai Super Kings  Mumbai Indians    20     3
# 136360       576       2  Chennai Super Kings  Mumbai Indians    20     4
# 136361       576       2  Chennai Super Kings  Mumbai Indians    20     5
# 136362       576       2  Chennai Super Kings  Mumbai Indians    20     6
#
#           batsman non_striker         bowler  is_super_over  ...  bye_runs  \
# ...

# %%
df.query("(batting_team == 'Chennai Super Kings' or bowling_team == 'Chennai Super Kings') and batsman == 'RA Jadeja'")
# Out:
#         match_id  inning         batting_team         bowling_team  over  \
# 27330        117       2     Rajasthan Royals  Chennai Super Kings    18
# 31892        137       2     Rajasthan Royals  Chennai Super Kings     6
# 31895        137       2     Rajasthan Royals  Chennai Super Kings     7
# 31896        137       2     Rajasthan Royals  Chennai Super Kings     7
# 31897        137       2     Rajasthan Royals  Chennai Super Kings     7
# ...          ...     ...                  ...                  ...   ...
# 136344       576       2  Chennai Super Kings       Mumbai Indians    18
# 136349       576       2  Chennai Super Kings       Mumbai Indians    18
# 136353       576       2  Chennai Super Kings       Mumbai Indians    19
# 136355       576       2  Chennai Super Kings       Mumbai Indians    19
# 136357       576       2  Chennai Super Kings       Mumbai Indians    20
#
#         ball    batsman non_striker          bowler  is_super_over  ...  \
# ...
